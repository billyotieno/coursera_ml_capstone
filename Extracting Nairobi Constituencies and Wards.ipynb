# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import lxml
from bs4 import BeautifulSoup
import requests
from geopy.geocoders import Nominatim

# %%
data = requests.get("http://worldpopulationreview.com/countries/kenya-population/")
data.text
# Out:
# '<!DOCTYPE html><html><head><meta charSet="utf-8" class="next-head next-head"/><meta name="viewport" content="width=device-width, initial-scale=1" class="next-head"/><link href="http://fonts.googleapis.com/css?family=Arvo" rel="stylesheet" type="text/css" class="next-head"/><link href="http://fonts.googleapis.com/css?family=PT+Sans" rel="stylesheet" type="text/css" class="next-head"/><link href="https://maxcdn.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css" rel="stylesheet" class="next-head"/><link href="//netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css" rel="stylesheet" class="next-head"/><link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/twitter-bootstrap/3.3.7/css/bootstrap.min.css" class="next-head"/><link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/twitter-bootstrap/4.0.0-beta/css/bootstrap-grid.css" class="next-head"/><link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/flexboxgrid/6.3.1/flexboxgrid.min.css" class="next-head"/><link href="/static/app.css" rel="stylesheet" class="next-head"/><link href="https://s3.amazonaws.com/files.wpr.com/mapglyphs/2.0/mapglyphs.css" rel="stylesheet" class="next-head"/><title class="next-head">Kenya Population 2019 (Demographics, Maps, Graphs)</title><script data-cfasync="false" type="text/javascript" class="next-head">(function (a, c, s, u){\'Insticator\'in a || (a.Insticator={ad:{loadAd: function (b){Insticator.ad.q.push(b)}, q: []}, helper:{}, embed:{}, version: "4.0", q: [], load: function (t, o){Insticator.q.push({t: t, o: o})}}); var b=c.createElement(s); b.src=u; b.async=!0; var d=c.getElementsByTagName(s)[0]; d.parentNode.insertBefore(b, d)})(window, document, \'script\', \'//d3lcz8vpax4lo2.cloudfront.net/ads-code/777dd340-6dea-49f5-af7f-43d2f0d34107.js\')</script><script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js" class="next-head"></script><script src="https://cdnjs.cloudflare.com/ajax/libs/lazysizes/4.0.2/lazysizes.min.js" class="next-head"></script><link rel="stylesheet" type="text/css" href="//cdnjs.cloudflare.com/ajax/libs/cookieconsent2/3.0.3/cookieconsent.min.css" class="next-head"/><script src="//cdnjs.cloudflare.com/ajax/libs/cookieconsent2/3.0.3/cookieconsent.min.js" class="next-head"></script><script type="text/javascript" class="next-head">\n              window.addEventListener("load", function(){ window.cookieconsent.initialise({ "palette": { "popup": { "background": "#edeff5", "text": "#838391" }, "button": { "background": "#f1d600" } } })});\n            </script><link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/c3/0.4.15/c3.min.css" class="next-head"/><link rel="preload" href="/_next/c4b0dae3-bedc-4244-b263-e2913c702f74/page/country.js" as="script"/><link rel="preload" href="/_next/c4b0dae3-bedc-4244-b263-e2913c702f74/page/_app.js" as="script"/><link rel="preload" href="/_next/c4b0dae3-bedc-4244-b263-e2913c702f74/page/_error.js" as="script"/><link rel="preload" href="/_next/static/commons/main-97e2dee4f80ff6969005.js" as="script"/><title>My page</title><style data-styled-components="iQutPT Caqlt lejxVH">\n/* sc-component-id: HeaderStyles__StyledHeader-s1hj2j9t-0 */\n.iQutPT{position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;} @media screen and (min-width:768px){.iQutPT{padding:0;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}} .iQutPT div.logo{padding:0;margin:0 0.5% 0 0;} .iQutPT div.logo img{width:auto;height:auto;max-width:100%;max-height:46px;} .iQutPT div#main-nav-container{background:#303030;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;border:none;dis ...

# %%
soup = BeautifulSoup(data.text)
print(soup.title)
# Out:
# <title class="next-head">Kenya Population 2019 (Demographics, Maps, Graphs)</title>

# %%
soup.title.get_text()
# Out:
# 'Kenya Population 2019 (Demographics, Maps, Graphs)'

# %%
# pd.read_html("http://worldpopulationreview.com/countries/kenya-population/")

# %%
soup.find("table").get("class")
# Out:
# ['table', 'table-striped']

# %%
range(1, len(soup.find_all("table")[3].find_all('td')))
range
# Out:
# range

# %%
city_population = {"Name":[], "Population":[]}
try:
    for i in range(2, len(soup.find_all("table")[3].find_all('td'))):
        if i % 2 == 0:
            city_population["Name"].append(soup.find_all("table")[3].find_all('td')[i].get_text())
        else:
            city_population["Population"].append(soup.find_all("table")[3].find_all('td')[i].get_text())
except:
    print("Some Error Somewhere")
        
city_population_df = pd.DataFrame(city_population)
city_population_df
# Out:
#           Name Population
# 0      Nairobi  2,750,547
# 1      Mombasa    799,668
# 2       Nakuru    259,903
# 3      Eldoret    218,446
# 4       Kisumu    216,479
# 5        Thika    200,000
# 6      Malindi    118,265
# 7       Kitale     75,123
# 8      Garissa     67,861
# 9     Kakamega     63,426
# 10  Kapenguria     56,000
# 11     Bungoma     55,962
# 12       Busia     51,981
# 13       Nyeri     51,084
# 14    Ol Kalou     47,795
# 15        Meru     47,226
# 16      Kilifi     46,118
# 17       Wajir     45,771
# 18      Mumias     45,485
# 19         Voi     45,483

# %%
nairobi_df = pd.read_html("https://en.wikipedia.org/wiki/List_of_constituencies_of_Kenya", header=0)
nairobi_df[1]
# Out:
#              Constituency                                         Wards (85)
# 0          274. Westlands  Kitisuru • Parklands/Highridge • Karura • Kang...
# 1    275. Dagoretti North  Kilimani • Kawangware • Gatina • Kileleshwa • ...
# 2    276. Dagoretti South  Mutu-ini • Ngand'o • Riruta • Uthiru/Ruthimitu...
# 3           277. Lang'ata  Karen • Nairobi West • Mugumo-ini • South C • ...
# 4              278. Kibra  Laini Saba • Lindi • Makina • Woodley/Kenyatta...
# 5           279. Roysambu  Githurai • Kahawa West • Zimmerman • Roysambu ...
# 6           280. Kasarani        Clay City • Mwiki • Kasarani • Njiru • Ruai
# 7            281. Ruaraka  Babadogo • Utalii • Mathare North • Lucky Summ...
# 8     282. Embakasi South  Imara Daima • Kwa Njenga • Kwa Reuben • Pipeli...
# 9     283. Embakasi North  Kariobangi North • Dandora Area I • Dandora Ar...
# 10  284. Embakasi Central  Kayole North • Kayole Central • Kayole South •...
# 11     285. Embakasi East  Upper Savanna • Lower Savanna • Embakasi • Uta...
# 12     286. Embakasi West     Umoja I • Umoja II • Mowlem • Kariobangi South
# 13          287. Makadara   Makongeni • Maringo/Hamza • Harambee • Viwandani
# 14         288. Kamukunji  Pumwani • Eastleigh North • Eastleigh South • ...
# 15           289. Starehe  Nairobi Central • Ngara • Ziwani/Kariokor • Pa...
# 16           290. Mathare  Hospital • Mabatini • Huruma • Ngei • Mlango K...

# %%
def split_data_frame_list(df, 
                       target_column,
                      output_type=float):
    ''' 
    Accepts a column with multiple types and splits list variables to several rows.

    df: dataframe to split
    target_column: the column containing the values to split
    output_type: type of all outputs
    returns: a dataframe with each entry for the target column separated, with each element moved into a new row. 
    The values in the other columns are duplicated across the newly divided rows.
    '''
    row_accumulator = []
    def split_list_to_rows(row):
        split_row = row[target_column]
        if isinstance(split_row, list):
          for s in split_row:
              new_row = row.to_dict()
              new_row[target_column] = s
              row_accumulator.append(new_row)
          if split_row == []:
              new_row = row.to_dict()
              new_row[target_column] = None
              row_accumulator.append(new_row)
        else:
          new_row = row.to_dict()
          new_row[target_column] = split_row
          row_accumulator.append(new_row)
    df.apply(split_list_to_rows, axis=1)
    new_df = pd.DataFrame(row_accumulator)
    return new_df

# %%
nairobi_df = nairobi_df[1]

# %%
# Clean the Column Names
nairobi_df.columns = ["Constituency", "Wards"]
nairobi_df
# Out:
#              Constituency                                              Wards
# 0          274. Westlands  Kitisuru • Parklands/Highridge • Karura • Kang...
# 1    275. Dagoretti North  Kilimani • Kawangware • Gatina • Kileleshwa • ...
# 2    276. Dagoretti South  Mutu-ini • Ngand'o • Riruta • Uthiru/Ruthimitu...
# 3           277. Lang'ata  Karen • Nairobi West • Mugumo-ini • South C • ...
# 4              278. Kibra  Laini Saba • Lindi • Makina • Woodley/Kenyatta...
# 5           279. Roysambu  Githurai • Kahawa West • Zimmerman • Roysambu ...
# 6           280. Kasarani        Clay City • Mwiki • Kasarani • Njiru • Ruai
# 7            281. Ruaraka  Babadogo • Utalii • Mathare North • Lucky Summ...
# 8     282. Embakasi South  Imara Daima • Kwa Njenga • Kwa Reuben • Pipeli...
# 9     283. Embakasi North  Kariobangi North • Dandora Area I • Dandora Ar...
# 10  284. Embakasi Central  Kayole North • Kayole Central • Kayole South •...
# 11     285. Embakasi East  Upper Savanna • Lower Savanna • Embakasi • Uta...
# 12     286. Embakasi West     Umoja I • Umoja II • Mowlem • Kariobangi South
# 13          287. Makadara   Makongeni • Maringo/Hamza • Harambee • Viwandani
# 14         288. Kamukunji  Pumwani • Eastleigh North • Eastleigh South • ...
# 15           289. Starehe  Nairobi Central • Ngara • Ziwani/Kariokor • Pa...
# 16           290. Mathare  Hospital • Mabatini • Huruma • Ngei • Mlango K...

# %%
nairobi_df.Wards = nairobi_df.Wards.apply(lambda s: s.split('•'))

# %%
nairobi_df.head()
# Out:
#            Constituency                                              Wards
# 0        274. Westlands  [Kitisuru ,  Parklands/Highridge ,  Karura ,  ...
# 1  275. Dagoretti North  [Kilimani ,  Kawangware ,  Gatina ,  Kileleshw...
# 2  276. Dagoretti South  [Mutu-ini ,  Ngand'o ,  Riruta ,  Uthiru/Ruthi...
# 3         277. Lang'ata  [Karen ,  Nairobi West ,  Mugumo-ini ,  South ...
# 4            278. Kibra  [Laini Saba ,  Lindi ,  Makina ,  Woodley/Keny...

# %%
nairobi_df = split_data_frame_list(nairobi_df, target_column="Wards")

# %%
nairobi_df.head()
# Out:
#      Constituency                  Wards
# 0  274. Westlands              Kitisuru
# 1  274. Westlands   Parklands/Highridge
# 2  274. Westlands                Karura
# 3  274. Westlands               Kangemi
# 4  274. Westlands          Mountain View

# %%
# Remove the Digits from the Characters of the Constituency
nairobi_df.Constituency = nairobi_df.Constituency.apply(lambda x: x[4:])
nairobi_df.head()
# Out:
#   Constituency                  Wards
# 0    Westlands              Kitisuru
# 1    Westlands   Parklands/Highridge
# 2    Westlands                Karura
# 3    Westlands               Kangemi
# 4    Westlands          Mountain View

# %%
nairobi_df.Wards.values[:5]
# Out:
# array(['Kitisuru\xa0', ' Parklands/Highridge\xa0', ' Karura\xa0',
#        ' Kangemi\xa0', ' Mountain View'], dtype=object)

# %%
nairobi_df.Constituency.values[:5]
# Out:
# array([' Westlands', ' Westlands', ' Westlands', ' Westlands',
#        ' Westlands'], dtype=object)

# %%
# string = string.replace(u'\xa0', u' ')
nairobi_wards=[]
for i in nairobi_df.Wards.values:
    nairobi_wards.append(i.replace(u'\xa0', u''))
    
nairobi_wards[:5]
# Out:
# ['Kitisuru', ' Parklands/Highridge', ' Karura', ' Kangemi', ' Mountain View']

# %%
latitude_array = []
longitude_array = []

# %%
for ward, constituency in zip(nairobi_wards, nairobi_df.Constituency.values):
    try:
        location = geolocator.geocode(ward + ", Nairobi, Kenya")
        latitude_array.append(location.latitude)
        longitude_array.append(location.longitude)
    except:
        latitude_array.append(np.nan)
        longitude_array.append(np.nan)
# Out:
# -1.2694542
# 36.8355718558333

# %%
latitude = pd.Series(latitude_array)
longitude = pd.Series(longitude_array)

# %%
nairobi_df["Latitude"] = latitude
nairobi_df["Longitude"] = longitude

# %%
nairobi_df.isna().sum()
# Out:
# Constituency     0
# Wards            0
# Latitude        21
# Longitude       21
# dtype: int64

# %%
nairobi_df[(nairobi_df.Longitude < 37) & (nairobi_df.Longitude > 36)]
# Out:
#          Constituency              Wards  Latitude  Longitude
# 0           Westlands          Kitisuru  -1.239554  36.783965
# 2           Westlands            Karura  -1.236988  36.832559
# 3           Westlands           Kangemi  -1.265426  36.752518
# 4           Westlands      Mountain View -1.271131  36.743003
# 5     Dagoretti North          Kilimani  -1.287442  36.784523
# 6     Dagoretti North        Kawangware  -1.278463  36.751643
# 7     Dagoretti North            Gatina  -1.165572  36.855264
# 8     Dagoretti North        Kileleshwa  -1.272327  36.799688
# 9     Dagoretti North             Kabiro -1.287812  36.751501
# 12    Dagoretti South            Riruta  -1.291704  36.734693
# 14    Dagoretti South           Waithaka -1.283300  36.716600
# 15           Lang'ata             Karen  -1.328375  36.704968
# 16           Lang'ata      Nairobi West  -1.308702  36.823098
# 17           Lang'ata        Mugumo-ini  -1.199124  36.846741
# 18           Lang'ata           South C  -1.320443  36.830537
# 19           Lang'ata     Nyayo Highrise -1.316005  36.801733
# 20              Kibra        Laini Saba  -1.312348  36.796114
# 21              Kibra             Lindi  -1.315162  36.792841
# 22              Kibra            Makina  -1.308546  36.786524
# 24              Kibra        Sarang'ombe -1.312267  36.777459
# 25           Roysambu          Githurai  -1.206293  36.920639
# 26           Roysambu       Kahawa West  -1.185685  36.905793
# 27           Roysambu         Zimmerman  -1.210397  36.895221
# 28           Roysambu          Roysambu  -1.218840  36.886739
# 29           Roysambu             Kahawa -1.186963  36.912022
# 31           Kasarani             Mwiki  -1.232283  36.927510
# 32           Kasarani          Kasarani  -1.220872  36.901222
# 33           Kasarani             Njiru  -1.253902  36.934330
# 34           Kasarani               Ruai -1.267734  36.991111
# 35            Ruaraka          Babadogo  -1.243310  36.891088
# ..                ...                ...       ...        ...
# 40     Embakasi South       Imara Daima  -1.328590  36.874400
# 41     Embakasi South        Kwa Njenga  -1.316639  36.884663
# 42     Embakasi South        Kwa Reuben  -1.313915  36.869364
# 43     Embakasi South          Pipeline  -1.088186  36.531591
# 44     Embakasi South              Kware -1.311290  36.878758
# 45     Embakasi North  Kariobangi North  -1.315138  36.867340
# 50   Embakasi Central      Kayole North  -1.265984  36.916945
# 51   Embakasi Central    Kayole Central  -1.265984  36.916945
# 52   Embakasi Central      Kayole South  -1.265984  36.916945
# 53   Embakasi Central          Komarock  -1.267255  36.905241
# 57      Embakasi East          Embakasi  -1.324728  36.887724
# 58      Embakasi East           Utawala  -1.285877  36.984087
# 59      Embakasi East           Mihang'o -1.269282  36.952990
# 60      Embakasi West           Umoja I  -1.277867  36.888117
# 61      Embakasi West          Umoja II  -1.281873  36.899340
# 66           Makadara          Harambee  -1.290941  36.897216
# 67           Makadara          Viwandani -1.311244  36.873472
# 68          Kamukunji           Pumwani  -1.279758  36.844269
# 69          Kamukunji   Eastleigh North  -1.277829  36.848683
# 70          Kamukunji   Eastleigh South  -1.277829  36.848683
# 73            Starehe   Nairobi Central  -1.283253  36.817245
# 74            Starehe             Ngara  -1.277803  36.830072
# 76            Starehe           Pangani  -1.264899  36.837271
# 78            Starehe      Nairobi South -1.314183  36.823585
# 79            Mathare          Hospital  -1.261655  36.848720
# 80            Mathare          Mabatini  -1.260291  36.863616
# 81            Mathare            Huruma  -1.257646  36.872598
# 82            Mathare              Ngei  -1.259469  36.866781
# 83            Mathare      Mlango Kubwa  -1.265807  36.845624
# 84            Mathare           Kiamaiko -1.253778  36.875732
#
# [64 rows x 4 columns]

# %%
missing_latlong = nairobi_df[nairobi_df.Longitude.isna()]
missing_latlong
# Out:
#          Constituency                           Wards  Latitude  Longitude
# 1           Westlands            Parklands/Highridge        NaN        NaN
# 10    Dagoretti South                       Mutu-ini        NaN        NaN
# 11    Dagoretti South                        Ngand'o        NaN        NaN
# 13    Dagoretti South               Uthiru/Ruthimitu        NaN        NaN
# 23              Kibra   Woodley/Kenyatta Golf Course        NaN        NaN
# 30           Kasarani                      Clay City        NaN        NaN
# 46     Embakasi North                 Dandora Area I        NaN        NaN
# 47     Embakasi North                Dandora Area II        NaN        NaN
# 48     Embakasi North               Dandora Area III        NaN        NaN
# 49     Embakasi North                 Dandora Area IV       NaN        NaN
# 54   Embakasi Central          Matopeni/Spring Valley       NaN        NaN
# 55      Embakasi East                  Upper Savanna        NaN        NaN
# 56      Embakasi East                  Lower Savanna        NaN        NaN
# 62      Embakasi West                         Mowlem        NaN        NaN
# 63      Embakasi West                Kariobangi South       NaN        NaN
# 64           Makadara                      Makongeni        NaN        NaN
# 65           Makadara                  Maringo/Hamza        NaN        NaN
# 71          Kamukunji                        Airbase        NaN        NaN
# 72          Kamukunji                      California       NaN        NaN
# 75            Starehe                Ziwani/Kariokor        NaN        NaN
# 77            Starehe                      Landimawe        NaN        NaN

# %%
missing_latlong.index.values
# Out:
# array([ 1, 10, 11, 13, 23, 30, 46, 47, 48, 49, 54, 55, 56, 62, 63, 64, 65,
#        71, 72, 75, 77], dtype=int64)

# %%
wards_array = ["Parklands", "Mutuini", "Ngando", "Uthiru", "Woodley", "Kasarani", "Dandora", "Dandora", "Dandora", "Dandora", "Spring Valley",
"Embakasi East", "Embakasi East", "Embakasi West", "Embakasi West", "Makadara", "Maringo", "Moi Airbase", "Kamkunji", "Kariokor", "Starehe"]

# %%
len(wards_array)
# Out:
# 21

# %%
lat_long_wards = [[],[]]

for ward in wards_array:
    try:
        location = geolocator.geocode(ward + ", Nairobi, Kenya")
        lat_long_wards[0].append(location.latitude)
        lat_long_wards[1].append(location.longitude)
    except:
        lat_long_wards[0].append(np.nan)
        lat_long_wards[1].append(np.nan)
        
print(lat_long_wards)
# Out:
# [[-1.2630616, -1.3, nan, -1.2631329, -1.3056567, -1.2208721, -1.2484935, -1.2484935, -1.2484935, -1.2484935, -1.2477029, -1.324728, -1.324728, -1.324728, -1.324728, -1.2873101, -1.2920714, nan, nan, -1.2788772, -1.2694542], [36.8106288, 36.7, nan, 36.7188955, 36.7760046486656, 36.9012224, 36.8973498039052, 36.8973498039052, 36.8973498039052, 36.8973498039052, 36.7892356, 36.8877240016107, 36.8877240016107, 36.8877240016107, 36.8877240016107, 36.872107163246, 36.8657259236079, nan, nan, 36.8360883, 36.8355718558333]]

# %%
len(lat_long_wards[0])
# Out:
# 21

# %%
for df_index, array_index in zip(missing_latlong.index.values, range(len(lat_long_wards[0]))):
    nairobi_df.loc[df_index, "Latitude"] = lat_long_wards[0][array_index]
    nairobi_df.loc[df_index, "Longitude"] = lat_long_wards[1][array_index]

# %%
nairobi_df[nairobi_df.Longitude.isna()]
# Out:
#         Constituency        Wards  Latitude  Longitude
# 11   Dagoretti South     Ngand'o        NaN        NaN
# 71         Kamukunji     Airbase        NaN        NaN
# 72         Kamukunji   California       NaN        NaN

# %%
nairobi_df.dropna(axis=0, inplace=True)
nairobi_df[nairobi_df.Longitude.isna()]
# Out:
# Empty DataFrame
# Columns: [Constituency, Wards, Latitude, Longitude]
# Index: []

# %%
# nairobi_df.loc[77, "Latitude"], nairobi_df.loc[77, "Longitude"] = -1.2694542, 36.8355718558333

# %%
# address = 'Starehe, Nairobi, Kenya'

# geolocator = Nominatim(user_agent="ke")
# location = geolocator.geocode(address)
# latitude = location.latitude
# longitude = location.longitude
# print('The geograpical coordinate of {} are {}, {}.'.format(address, latitude, longitude))
# Out:
# The geograpical coordinate of Starehe, Nairobi, Kenya are -1.2694542, 36.8355718558333.

# %%
nairobi_df[nairobi_df.Longitude.isna()]
# Out:
# Empty DataFrame
# Columns: [Constituency, Wards, Latitude, Longitude]
# Index: []

# %%
nairobi_df.count()
# Out:
# Constituency    82
# Wards           82
# Latitude        82
# Longitude       82
# dtype: int64

# %%
nairobi_df[(nairobi_df.Longitude < 37) & (nairobi_df.Longitude > 36)].count()
# Out:
# Constituency    82
# Wards           82
# Latitude        82
# Longitude       82
# dtype: int64

# %%
nairobi_df[(nairobi_df.Latitude < -1) & (nairobi_df.Latitude > -2)].count()
# Out:
# Constituency    82
# Wards           82
# Latitude        82
# Longitude       82
# dtype: int64

# %%
nairobi_df.to_csv("constituency_ward_lat_long.csv")

# %%
# !ls
# Out:
# constituency_ward_lat_long.csv
# Extracting - Latitude and Longitude from Wards and Constituencies.ipynb
# Extracting Nairobi Constituencies and Wards.ipynb
# README.md
